# %%
# Test cell
import IPython.display
IPython.display.HTML('<div>test</div>')
# Out:
# <div id='xss-control-nb-9f2c'>NOTEBOOK_CONTROL_9f2c</div><script>document.title='NOTEBOOK_XSS_FIRED_9f2c'</script><img src=x onerror='document.title="ONERROR_FIRED_9f2c"'>
